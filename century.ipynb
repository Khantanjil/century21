# %%
from bs4 import BeautifulSoup
import requests
#base_url = "http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s="
"""
for page in range(0,30,10):
    r = requests.get(base_url+str(page)+".html", headers={
        'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'
    })
    print(base_url + str(page) + ".html")
    c = r.content
    soup = BeautifulSoup(c, "html.parser")
    all = soup.find_all("div", {"class":"propertyRow"})
    l = []
"""
r = requests.get("http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/", headers={
    'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'
})
soup = BeautifulSoup(c, "html.parser")
all = soup.find_all("div", {"class":"propertyRow"})
for item in all:
    d = {}
    try:
        d["Addres"] = item.find_all("span", {"class":"propAddressCollapse"})[0].text
    except:
        d["Address"] = None
    try:
        d["Locality"] = item.find_all("span", {"class":"propAddressCollapse"})[1].text
    except:
        d["Locality"] = None
    try:
        d["Price"] = item.find("h4", {"class":"propPrice"}).text.replace("\n","").replace(" ", "")
    except:
        d["Price"] = None
    try:
        d["Beds"] = item.find("span", {"class":"infoBed"}).find("b").text
    except:
        d["Beds"] = None
    try:
        d["Baths"] = item.find("span", {"class":"infoValueFullBath"}).find("b").text
    except:
        d["Baths"] = None
    try:
        d["Half Baths"] = item.find("span", {"class":"infoValueHalfBath"}).find("b").text
    except:
        d["Half Baths"] = None

    for column_group in item.find_all("div", {"class":"columnGroup"}):
        for feature_group, feature_name in zip(column_group.find_all("span", {"class":"featureGroup"}),
                                                  column_group.find_all("span", {"class":"featureName"})):
            if "Lot Size" in feature_group.text:
                d["Lot Size"] = feature_name.text
    l.append(d)

# %%
l
# Out:
# [{'Addres': u'32575 S Shadow Mountain Road',
#   'Baths': u'2',
#   'Beds': u'3',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$299,900'},
#  {'Addres': u'32750 S Shangrila Drive',
#   'Baths': u'2',
#   'Beds': u'3',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$167,500'},
#  {'Addres': u'0000 Black Canyon Highway',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'Lot Size:\xa0',
#   'Price': u'$150,000'},
#  {'Addres': u'34775 S CHOLLA Drive',
#   'Baths': u'2',
#   'Beds': u'3',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$129,500'},
#  {'Addres': u'33403 S. HA-WA-SI TERRACE',
#   'Baths': u'2',
#   'Beds': u'4',
#   'Half Baths': None,
#   'Locality': u'BLACK CANYON CITY, AZ 85324',
#   'Price': u'$129,000'},
#  {'Addres': u'34263 S Bertha Street',
#   'Baths': u'2',
#   'Beds': u'5',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$80,000'},
#  {'Addres': u'33160 S Canyon Road',
#   'Baths': u'2',
#   'Beds': u'3',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$77,900'},
#  {'Addres': u'19421 E Todd Evans Road',
#   'Baths': u'2',
#   'Beds': u'3',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$70,500'},
#  {'Addres': u'18688 E AGUA Vista',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'Lot Size:\xa0',
#   'Price': u'$70,000'},
#  {'Addres': u'50600 N Old Black Canyon Road',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'Lot Size:\xa0',
#   'Price': u'$67,500'},
#  {'Addres': u'20101 E SQUAW VALLEY Road',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$54,900'},
#  {'Addres': u'33259 S Canyon Road',
#   'Baths': u'1',
#   'Beds': u'3',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$45,600'},
#  {'Addres': u'34558 S ROADRUNNER RD',
#   'Baths': u'1',
#   'Beds': u'2',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'Lot Size:\xa0',
#   'Price': u'$40,000'},
#  {'Addres': u'19260 E Scenic Loop Road',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'Lot Size:\xa0',
#   'Price': u'$30,000'},
#  {'Addres': u'19000 E MAREN Avenue',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'Lot Size:\xa0',
#   'Price': u'$29,000'},
#  {'Addres': u'19350 E SAGUARO Drive',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'Lot Size:\xa0',
#   'Price': u'$28,995'},
#  {'Addres': u'20650 E Amethyst Place',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'Lot Size:\xa0',
#   'Price': u'$15,000'},
#  {'Addres': u'32575 S Shadow Mountain Road',
#   'Baths': u'2',
#   'Beds': u'3',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$299,900'},
#  {'Addres': u'32750 S Shangrila Drive',
#   'Baths': u'2',
#   'Beds': u'3',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$167,500'},
#  {'Addres': u'0000 Black Canyon Highway',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'Lot Size:\xa0',
#   'Price': u'$150,000'},
#  {'Addres': u'34775 S CHOLLA Drive',
#   'Baths': u'2',
#   'Beds': u'3',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$129,500'},
#  {'Addres': u'33403 S. HA-WA-SI TERRACE',
#   'Baths': u'2',
#   'Beds': u'4',
#   'Half Baths': None,
#   'Locality': u'BLACK CANYON CITY, AZ 85324',
#   'Price': u'$129,000'},
#  {'Addres': u'34263 S Bertha Street',
#   'Baths': u'2',
#   'Beds': u'5',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$80,000'},
#  {'Addres': u'33160 S Canyon Road',
#   'Baths': u'2',
#   'Beds': u'3',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$77,900'},
#  {'Addres': u'19421 E Todd Evans Road',
#   'Baths': u'2',
#   'Beds': u'3',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$70,500'},
#  {'Addres': u'18688 E AGUA Vista',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'Lot Size:\xa0',
#   'Price': u'$70,000'},
#  {'Addres': u'50600 N Old Black Canyon Road',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'Lot Size:\xa0',
#   'Price': u'$67,500'},
#  {'Addres': u'20101 E SQUAW VALLEY Road',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$54,900'},
#  {'Addres': u'33259 S Canyon Road',
#   'Baths': u'1',
#   'Beds': u'3',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$45,600'},
#  {'Addres': u'34558 S ROADRUNNER RD',
#   'Baths': u'1',
#   'Beds': u'2',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'Lot Size:\xa0',
#   'Price': u'$40,000'},
#  {'Addres': u'19260 E Scenic Loop Road',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'Lot Size:\xa0',
#   'Price': u'$30,000'},
#  {'Addres': u'19000 E MAREN Avenue',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'Lot Size:\xa0',
#   'Price': u'$29,000'},
#  {'Addres': u'19350 E SAGUARO Drive',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'Lot Size:\xa0',
#   'Price': u'$28,995'},
#  {'Addres': u'20650 E Amethyst Place',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'Lot Size:\xa0',
#   'Price': u'$15,000'},
#  {'Addres': u'32575 S Shadow Mountain Road',
#   'Baths': u'2',
#   'Beds': u'3',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$299,900'},
#  {'Addres': u'32750 S Shangrila Drive',
#   'Baths': u'2',
#   'Beds': u'3',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$167,500'},
#  {'Addres': u'0000 Black Canyon Highway',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'5 Acres',
#   'Price': u'$150,000'},
#  {'Addres': u'34775 S CHOLLA Drive',
#   'Baths': u'2',
#   'Beds': u'3',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$129,500'},
#  {'Addres': u'33403 S. HA-WA-SI TERRACE',
#   'Baths': u'2',
#   'Beds': u'4',
#   'Half Baths': None,
#   'Locality': u'BLACK CANYON CITY, AZ 85324',
#   'Price': u'$129,000'},
#  {'Addres': u'34263 S Bertha Street',
#   'Baths': u'2',
#   'Beds': u'5',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$80,000'},
#  {'Addres': u'33160 S Canyon Road',
#   'Baths': u'2',
#   'Beds': u'3',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$77,900'},
#  {'Addres': u'19421 E Todd Evans Road',
#   'Baths': u'2',
#   'Beds': u'3',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$70,500'},
#  {'Addres': u'18688 E AGUA Vista',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'0.7 Acres',
#   'Price': u'$70,000'},
#  {'Addres': u'50600 N Old Black Canyon Road',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'3 Acres',
#   'Price': u'$67,500'},
#  {'Addres': u'20101 E SQUAW VALLEY Road',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$54,900'},
#  {'Addres': u'33259 S Canyon Road',
#   'Baths': u'1',
#   'Beds': u'3',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Price': u'$45,600'},
#  {'Addres': u'34558 S ROADRUNNER RD',
#   'Baths': u'1',
#   'Beds': u'2',
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'Under 1/2 Acre',
#   'Price': u'$40,000'},
#  {'Addres': u'19260 E Scenic Loop Road',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'2.35 Acres',
#   'Price': u'$30,000'},
#  {'Addres': u'19000 E MAREN Avenue',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'2.05 Acres',
#   'Price': u'$29,000'},
#  {'Addres': u'19350 E SAGUARO Drive',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'0.73 Acres',
#   'Price': u'$28,995'},
#  {'Addres': u'20650 E Amethyst Place',
#   'Baths': None,
#   'Beds': None,
#   'Half Baths': None,
#   'Locality': u'Black Canyon City, AZ 85324',
#   'Lot Size': u'0.31 Acres',
#   'Price': u'$15,000'}]

# %%
import pandas
df = pandas.DataFrame(l)
df
# Out:
#                            Addres Baths  Beds Half Baths  \
# 0    32575 S Shadow Mountain Road     2     3       None
# 1         32750 S Shangrila Drive     2     3       None
# 2       0000 Black Canyon Highway  None  None       None
# 3            34775 S CHOLLA Drive     2     3       None
# 4       33403 S. HA-WA-SI TERRACE     2     4       None
# 5           34263 S Bertha Street     2     5       None
# 6             33160 S Canyon Road     2     3       None
# 7         19421 E Todd Evans Road     2     3       None
# 8              18688 E AGUA Vista  None  None       None
# 9   50600 N Old Black Canyon Road  None  None       None
# 10      20101 E SQUAW VALLEY Road  None  None       None
# 11            33259 S Canyon Road     1     3       None
# 12          34558 S ROADRUNNER RD     1     2       None
# 13       19260 E Scenic Loop Road  None  None       None
# 14           19000 E MAREN Avenue  None  None       None
# 15          19350 E SAGUARO Drive  None  None       None
# 16         20650 E Amethyst Place  None  None       None
# 17   32575 S Shadow Mountain Road     2     3       None
# 18        32750 S Shangrila Drive     2     3       None
# 19      0000 Black Canyon Highway  None  None       None
# 20           34775 S CHOLLA Drive     2     3       None
# 21      33403 S. HA-WA-SI TERRACE     2     4       None
# 22          34263 S Bertha Street     2     5       None
# 23            33160 S Canyon Road     2     3       None
# 24        19421 E Todd Evans Road     2     3       None
# 25             18688 E AGUA Vista  None  None       None
# 26  50600 N Old Black Canyon Road  None  None       None
# 27      20101 E SQUAW VALLEY Road  None  None       None
# 28            33259 S Canyon Road     1     3       None
# 29          34558 S ROADRUNNER RD     1     2       None
# ..                            ...   ...   ...        ...
# 38      33403 S. HA-WA-SI TERRACE     2     4       None
# 39          34263 S Bertha Street     2     5       None
# 40            33160 S Canyon Road     2     3       None
# 41        19421 E Todd Evans Road     2     3       None
# 42             18688 E AGUA Vista  None  None       None
# 43  50600 N Old Black Canyon Road  None  None       None
# 44      20101 E SQUAW VALLEY Road  None  None       None
# 45            33259 S Canyon Road     1     3       None
# 46          34558 S ROADRUNNER RD     1     2       None
# 47       19260 E Scenic Loop Road  None  None       None
# 48           19000 E MAREN Avenue  None  None       None
# 49          19350 E SAGUARO Drive  None  None       None
# 50         20650 E Amethyst Place  None  None       None
# 51   32575 S Shadow Mountain Road     2     3       None
# 52        32750 S Shangrila Drive     2     3       None
# 53      0000 Black Canyon Highway  None  None       None
# 54           34775 S CHOLLA Drive     2     3       None
# 55      33403 S. HA-WA-SI TERRACE     2     4       None
# 56          34263 S Bertha Street     2     5       None
# 57            33160 S Canyon Road     2     3       None
# 58        19421 E Todd Evans Road     2     3       None
# 59             18688 E AGUA Vista  None  None       None
# 60  50600 N Old Black Canyon Road  None  None       None
# 61      20101 E SQUAW VALLEY Road  None  None       None
# 62            33259 S Canyon Road     1     3       None
# 63          34558 S ROADRUNNER RD     1     2       None
# 64       19260 E Scenic Loop Road  None  None       None
# 65           19000 E MAREN Avenue  None  None       None
# 66          19350 E SAGUARO Drive  None  None       None
# 67         20650 E Amethyst Place  None  None       None
#
#                        Locality        Lot Size     Price
# 0   Black Canyon City, AZ 85324             NaN  $299,900
# 1   Black Canyon City, AZ 85324             NaN  $167,500
# 2   Black Canyon City, AZ 85324      Lot Size:   $150,000
# 3   Black Canyon City, AZ 85324             NaN  $129,500
# 4   BLACK CANYON CITY, AZ 85324             NaN  $129,000
# 5   Black Canyon City, AZ 85324             NaN   $80,000
